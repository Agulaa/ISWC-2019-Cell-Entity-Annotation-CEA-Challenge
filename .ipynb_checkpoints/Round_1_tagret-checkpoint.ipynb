# %%
import pandas as pd 
import numpy as np

# %%
df_target = pd.read_csv("../CEA_Round1_Targets.csv", header=None, nrows=100)
df_target.columns=["Table_id", "Column_id", "Row_id"]

# %%
df_target["DBpedia_entity"] = ""
df_target["Cell"] = ""

# %%
df_target.head()
# Out:
#                          Table_id  Column_id  Row_id DBpedia_entity Cell
# 0   50245608_0_871275842592178099          0     154
# 1  39107734_2_2329160387535788734          1      32
# 2  22864497_0_8632623712684511496          0     227
# 3  66009064_0_9148652238372261251          0      15
# 4  21362676_0_6854186738074119688          1      75

# %%
def capitalize_word(word):
    return word.capitalize()

# %%
def remove_special_signs(word):
    result = ""
    for w in word:
        if w.isalpha() or w=="'" or w.isspace():
            result += w 
    return result

# %%
def replace_space(word):
    try:
        return word.replace(" ", "_")
    except:
        print(word)
        return word

# %%
def find_entity(df, column_id, row_id):
    try:
        cell = df.iloc[row_id, column_id]
        cell = remove_special_signs(cell)
        cell = capitalize_word(cell)
        cell = replace_space(cell)
        return f"http://dbpedia.org/resource/{cell}", cell
    except:
        return np.nan, np.nan

# %%
df_target = df_target.sort_values("Table_id").reset_index(drop=True)
first_table = df_target["Table_id"].unique()[0]

# %%
def make_for_row(row):
    global first_table
    table_id = row["Table_id"]
    if first_table == table_id:
         df = pd.read_csv(f"../CEA_Round1/{table_id}.csv", header=None)
    else:
        df = pd.read_csv(f"../CEA_Round1/{table_id}.csv", header=None)
        first_table = table_id
    column_id = row["Column_id"]
    row_id = row["Row_id"]
    path, cell = find_entity(df, column_id, row_id)
    row["DBpedia_entity"]= path
    row["Cell"]=cell
    return row

# %%
df_target.head()
# Out:
#                          Table_id  Column_id  Row_id  \
# 0  13719111_1_5719401842463579519          0     132
# 1  13719111_1_5719401842463579519          0     112
# 2  13719111_1_5719401842463579519          0     443
# 3  13719111_1_5719401842463579519          0     308
# 4  13719111_1_5719401842463579519          0      48
#
#                                       DBpedia_entity                   Cell
# 0           http://dbpedia.org/resource/Brown_parrot           Brown_parrot
# 1      http://dbpedia.org/resource/Common_greenshank      Common_greenshank
# 2      http://dbpedia.org/resource/Greybacked_fiscal      Greybacked_fiscal
# 3  http://dbpedia.org/resource/Snowyheaded_robinchat  Snowyheaded_robinchat
# 4    http://dbpedia.org/resource/Lappetfaced_vulture    Lappetfaced_vulture

# %%
df_target = df_target.apply(make_for_row, axis=1)

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
# Table_id          100 non-null object
# Column_id         100 non-null int64
# Row_id            100 non-null int64
# DBpedia_entity    100 non-null object
# Cell              100 non-null object
# dtypes: int64(2), object(3)
# memory usage: 4.0+ KB

# %%
df_target
# Out:
#                           Table_id  Column_id  Row_id  \
# 0   13719111_1_5719401842463579519          0     132
# 1   13719111_1_5719401842463579519          0     112
# 2   13719111_1_5719401842463579519          0     443
# 3   13719111_1_5719401842463579519          0     308
# 4   13719111_1_5719401842463579519          0      48
# 5   13719111_1_5719401842463579519          0     321
# 6   13719111_1_5719401842463579519          0     123
# 7   13719111_1_5719401842463579519          0     351
# 8   16767252_0_2409448375013995751          1      74
# 9   20135078_0_7570343137119682530          1      87
# 10  21245481_0_8730460088443117515          1     103
# 11  21245481_0_8730460088443117515          1     130
# 12  21245481_0_8730460088443117515          1     115
# 13  21245481_0_8730460088443117515          1      64
# 14  21362676_0_6854186738074119688          1      75
# 15  22864497_0_8632623712684511496          0     227
# 16  22864497_0_8632623712684511496          0     322
# 17  22864497_0_8632623712684511496          0     171
# 18  24036779_0_5608105867560183058          0      13
# 19  25404227_0_2240631045609013057          1      92
# 73                http://dbpedia.org/resource/Faceoff
# 74  http://dbpedia.org/resource/Archives_of_intern...
# 75                http://dbpedia.org/resource/Lacseul
# 76  http://dbpedia.org/resource/Asparagus_densiflorus
# 77      http://dbpedia.org/resource/Lygodium_palmatum
# 78      http://dbpedia.org/resource/Acacia_longifolia
# 79  http://dbpedia.org/resource/Thunbergia_grandif...
# 80       http://dbpedia.org/resource/Litsea_glutinosa
# 81       http://dbpedia.org/resource/Eastern_chipmunk
# 82         http://dbpedia.org/resource/Orchard_oriole
# 83           http://dbpedia.org/resource/Tree_swallow
# 84  http://dbpedia.org/resource/Super_mario_allsta...
# 85    http://dbpedia.org/resource/Gran_turismo__aspec
# 86                  http://dbpedia.org/resource/Fifa_
# 87  http://dbpedia.org/resource/The_curse_of_monke...
# 88  http://dbpedia.org/resource/World_of_warcraft_...
# 89               http://dbpedia.org/resource/Sim_city
# 90      http://dbpedia.org/resource/Singstar_pop_hits
# 91               http://dbpedia.org/resource/Die_sims
# 92   http://dbpedia.org/resource/Star_wars_clone_wars
# 93            http://dbpedia.org/resource/Rijksmuseum
# 94  http://dbpedia.org/resource/State_hermitage_mu...
# 95  http://dbpedia.org/resource/San_diego_museum_o...
# 96             http://dbpedia.org/resource/Fellbarrow
# 97              http://dbpedia.org/resource/Calf_crag
# 98          http://dbpedia.org/resource/Lingmoor_fell
# 99            http://dbpedia.org/resource/Kidsty_pike
#
#                                                  Cell
# 0                                        Brown_parrot
# 1                                   Common_greenshank
# 2                                   Greybacked_fiscal
# 3                               Snowyheaded_robinchat
# 4                                 Lappetfaced_vulture
# 5                              Brownbacked_scrubrobin
# 6                                Blackbilled_wooddove
# 7                                  Rattling_cisticola
# 8                                            Das_boot
# 9                             The_battleship_potemkin
# 10                                    Broken_bow_lake
# 11                                   Thunderbird_lake
# 12                                           Kaw_lake
# 13                                 Harlan_county_lake
# 14                                          King_kong
# 15                              Need_for_speed_carbon
# 16                                          Timeshift
# 17                    James_cameron's_avatar_the_game
# 18                             Bosnia_and_herzegovina
# 19                                        Three_kings
# 20                                  New_taiwan_dollar
# 21                                    St_helena_pound
# 22                                   Paulinus_of_nola
# 23                                         Pope_linus
# 24                                 Batman_arkham_city
# 25                The_legend_of_zelda_ocarina_of_time
# 26                                      Metroid_prime
# 27                                          Max_weber
# 28                                           Swingers
# 29                                     The_wild_bunch
# ..                                                ...
# 70                                          Greenland
# 71                                 Dead_poets_society
# 72  Legend_of_zelda_majora's_maskthe_legend_of_zel...
# 73                                            Faceoff
# 74                      Archives_of_internal_medicine
# 75                                            Lacseul
# 76                              Asparagus_densiflorus
# 77                                  Lygodium_palmatum
# 78                                  Acacia_longifolia
# 79                             Thunbergia_grandiflora
# 80                                   Litsea_glutinosa
# 81                                   Eastern_chipmunk
# 82                                     Orchard_oriole
# 83                                       Tree_swallow
# 84            Super_mario_allstars__super_mario_world
# 85                                Gran_turismo__aspec
# 86                                              Fifa_
# 87                         The_curse_of_monkey_island
# 88    World_of_warcraft_wrath_of_the_lich_king__addon
# 89                                           Sim_city
# 90                                  Singstar_pop_hits
# 91                                           Die_sims
# 92                               Star_wars_clone_wars
# 93                                        Rijksmuseum
# 94                             State_hermitage_museum
# 95                            San_diego_museum_of_art
# 96                                         Fellbarrow
# 97                                          Calf_crag
# 98                                      Lingmoor_fell
# 99                                        Kidsty_pike
#
# [100 rows x 5 columns]

# %%
from langdetect import detect

# %%
lang = detect("Ein, zwei, drei, vier")

# %%
lang
# Out:
# 'de'

# %%
'TREE SWALLOW'
# Out:
# 'Tree swallow'
